# %% [markdown]
# ### Using BeautifulSoup to get NBA Advanced & Average Player stats

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL for the 2025 NBA advanced stats
url = "https://www.basketball-reference.com/leagues/NBA_2025_advanced.html"

# Set headers to mimic a real browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"
}

# Get the webpage content
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# Locate the correct table (ID: "advanced")
table = soup.find("table", {"id": "advanced"})

# Check if the table exists
if table:
    # Extract headers
    headers = [th.get_text() for th in table.find("thead").find_all("th")]

    # Extract rows
    rows = []
    for row in table.find("tbody").find_all("tr"):
        cols = [td.get_text() for td in row.find_all("td")]
        if cols:  # Ignore empty rows
            rows.append(cols)

    # Convert to DataFrame
    df = pd.DataFrame(rows, columns=headers[1:])  # Skip the rank column

    # Show the top rows
    print(df.head())

    # Save the data to a CSV file
    df.to_csv("NBA_Advanced_Stats_2025.csv", index=False)
    print("Data saved to nba_advanced_stats_2025.csv")
# Out:
#             Player Age Team Pos   G  GS    MP   PER   TS%  3PAr  ...  USG%  \
# 0    Mikal Bridges  28  NYK  SF  67  67  2531  13.7  .583  .410  ...  19.1
# 1  Anthony Edwards  23  MIN  SG  67  67  2442  19.9  .592  .493  ...  31.5
# 2        Josh Hart  29  NYK  SG  64  64  2417  16.9  .622  .325  ...  15.5
# 3     Devin Booker  28  PHO  SG  63  63  2357  19.7  .594  .407  ...  28.9
# 4      Jalen Green  22  HOU  SG  69  69  2307  15.2  .547  .470  ...  27.1
#
#    OWS  DWS   WS WS/48 OBPM  DBPM   BPM VORP Awards
# 0  3.0  1.5  4.5  .086  0.3  -1.0  -0.7  0.9
# 1  3.6  3.1  6.8  .133  4.3  -0.2   4.1  3.8
# 2  4.9  3.1  7.9  .158  1.4   1.5   3.0  3.0
# 3  5.6  0.6  6.2  .127  2.9  -2.1   0.8  1.6
# 4  1.8  2.8  4.6  .097  1.3  -0.5   0.8  1.6
#
# [5 rows x 28 columns]
# Data saved to nba_advanced_stats_2025.csv

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL for the 2024-25 NBA per-game stats
url = "https://www.basketball-reference.com/leagues/NBA_2025_per_game.html"

# Set headers to mimic a real browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"
}

# Get the webpage content
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# Locate the correct table (ID: "per_game_stats")
table = soup.find("table", {"id": "per_game_stats"})

# Check if the table exists
if table:
    # Extract headers
    headers = [th.get_text() for th in table.find("thead").find_all("th")]

    # Extract rows
    rows = []
    for row in table.find("tbody").find_all("tr"):
        cols = [td.get_text() for td in row.find_all("td")]
        if cols:  # Ignore empty rows
            rows.append(cols)

    # Convert to DataFrame
    df = pd.DataFrame(rows, columns=headers[1:])  # Skip the rank column

    # Display the DataFrame
    print(df.head())

    # Save the data to a CSV file
    df.to_csv("NBA_Average_Stats_2025.csv", index=False)
    print("Data saved to nba_2024_25_per_game_stats.csv")
# Out:
#                     Player Age Team Pos   G  GS    MP    FG   FGA   FG%  ...  \
# 0  Shai Gilgeous-Alexander  26  OKC  PG  66  66  34.4  11.4  21.6  .526  ...
# 1    Giannis Antetokounmpo  30  MIL  PF  55  55  33.9  12.1  20.0  .603  ...
# 2            Nikola JokiÄ  29  DEN   C  62  62  36.5  11.1  19.4  .575  ...
# 3          Anthony Edwards  23  MIN  SG  67  67  36.4   9.1  20.5  .444  ...
# 4            Luka DonÄiÄ  25  2TM  PG  37  37  35.2   9.1  20.7  .439  ...
#
#    ORB   DRB   TRB   AST  STL  BLK  TOV   PF   PTS Awards
# 0  0.9   4.1   5.0   6.2  1.8  1.0  2.5  2.2  33.0
# 1  2.3   9.8  12.1   6.0  0.8  1.2  3.3  2.5  30.4
# 2  2.9  10.0  12.8  10.3  1.8  0.7  3.3  2.3  29.1
# 3  0.7   5.1   5.8   4.6  1.1  0.6  3.2  1.9  27.6
# 4  0.9   7.6   8.5   7.9  2.0  0.4  3.7  2.6  27.4
#
# [5 rows x 30 columns]
# Data saved to nba_2024_25_per_game_stats.csv

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL for NBA Team Ratings
url = "https://www.basketball-reference.com/leagues/NBA_2025_ratings.html"

# Set headers to mimic a real browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"
}

# Get the webpage content
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# Locate the correct table
table = soup.find("table", {"id": "ratings"})

# Debugging: Print the table HTML if found
if table:
    print("Table found! Extracting data...\n")
    print(table.prettify()[:1000])  # Print the first 1000 characters of the table for inspection

    # Extract headers
    header_th = table.find("thead").find_all("th")
    headers = [th.get_text(strip=True) for th in header_th]
    print(f"Extracted headers: {headers}")  # Debugging step

    # Extract rows
    rows = []
    for row in table.find("tbody").find_all("tr"):
        cols = [td.get_text(strip=True) for td in row.find_all("td")]

        # Only append rows with data
        if cols:
            rows.append(cols)

    # Debugging: Check if rows are extracted
    if not rows:
        print("⚠️ No rows extracted! The table might be empty, hidden, or JavaScript-rendered.")
    else:
        print(f"✅ Extracted {len(rows)} rows successfully.")  # Debugging step
        print(f"First row sample: {rows[0]}")  # Print first row to verify data

    # Convert to DataFrame only if data is available
    if rows:
        # Ensure headers match row length
        headers = headers[:len(rows[0])]  # Trim to match row column count

        df = pd.DataFrame(rows, columns=headers)  # Match columns dynamically

        # Show first few rows
        print(df.head())

        # Save to CSV
        df.to_csv("NBA_Team_Needs_2025.csv", index=False)
        print("✅ Data saved to NBA_Team_Needs_2025.csv")
else:
    print("⚠️ Table with id='ratings' NOT found. Check if the page structure has changed or data is loaded via JavaScript.")

# %%
# Out:
# ✅ Merged Data (First 10 Rows):
#                     Player   Age Team_x Pos     G    GS    MP    FG   FGA  \
# 0  Shai Gilgeous-Alexander  26.0    OKC  PG  66.0  66.0  34.4  11.4  21.6
# 1    Giannis Antetokounmpo  30.0    MIL  PF  55.0  55.0  33.9  12.1  20.0
# 2            Nikola JokiÄ  29.0    DEN   C  62.0  62.0  36.5  11.1  19.4
# 3          Anthony Edwards  23.0    MIN  SG  67.0  67.0  36.4   9.1  20.5
# 4            Luka DonÄiÄ  25.0    2TM  PG  37.0  37.0  35.2   9.1  20.7
# 5            Luka DonÄiÄ  25.0    DAL  PG  22.0  22.0  35.7   9.8  21.2
# 6            Luka DonÄiÄ  25.0    LAL  PG  15.0  15.0  34.5   8.0  20.0
# 7             Jayson Tatum  26.0    BOS  PF  63.0  63.0  36.6   9.2  20.3
# 8             Kevin Durant  36.0    PHO  PF  56.0  56.0  36.9   9.5  18.1
# 9            Jalen Brunson  28.0    NYK  PG  61.0  61.0  35.4   9.1  18.7
#
#      FG%  ...   TRB   AST  STL  BLK  TOV   PF   PTS  Awards  Team_y  Salary
# 0  0.526  ...   5.0   6.2  1.8  1.0  2.5  2.2  33.0     NaN     NaN     NaN
# 1  0.603  ...  12.1   6.0  0.8  1.2  3.3  2.5  30.4     NaN     NaN     NaN
# 2  0.575  ...  12.8  10.3  1.8  0.7  3.3  2.3  29.1     NaN     NaN     NaN
# 3  0.444  ...   5.8   4.6  1.1  0.6  3.2  1.9  27.6     NaN     NaN     NaN
# 4  0.439  ...   8.5   7.9  2.0  0.4  3.7  2.6  27.4     NaN     NaN     NaN
# 5  0.464  ...   8.3   7.8  2.0  0.4  3.4  2.6  28.1     NaN     NaN     NaN
# 6  0.400  ...   8.8   8.1  1.9  0.5  4.2  2.6  26.2     NaN     NaN     NaN
# 7  0.454  ...   8.7   5.9  1.1  0.5  3.0  2.2  27.1     NaN     NaN     NaN
# 8  0.526  ...   6.1   4.2  0.8  1.3  3.1  1.7  26.4     NaN     NaN     NaN
# 9  0.490  ...   3.0   7.4  1.0  0.1  2.5  2.2  26.3     NaN     NaN     NaN
#
# [10 rows x 32 columns]
#
# ✅ Data saved to 'NBA_Player_Data_With_Salaries.csv'

# %% [markdown]
# ### Looking at the Updated Files

# %%
Advanced_Stats_df = pd.read_csv("NBA_Advanced_Stats_2025.csv")  # Replace with your file path
Advanced_Stats_df.columns
# Out:
# Index(['Player', 'Age', 'Team', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'Awards'],
#       dtype='object')

# %%
Average_Stats_df = pd.read_csv("NBA_Average_Stats_2025.csv")  # Replace with your file path
Average_Stats_df.columns
# Out:
# Index(['Player', 'Age', 'Team', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards'],
#       dtype='object')

# %%
Team_Needs_df = pd.read_csv("NBA_Team_Needs_2025.csv")  # Replace with your file path
Team_Needs_df.columns
# Out:
# Index(['Unnamed: 0', 'Unadjusted', 'Adjusted', 'Rk', 'Team', 'Conf', 'Div',
#        'W', 'L', 'W/L%', 'MOV', 'ORtg', 'DRtg', 'NRtg'],
#       dtype='object')

# %%
Player_Salary_df = pd.read_csv("NBA_Player_Salary.csv")  # Replace with your file path
Player_Salary_df
# Out:
#       Rk                 Player   Tm    2024-25    2025-26    2026-27  \
# 0      1          Stephen Curry  GSW  $55761216  $59606817  $62587158
# 1      2            Joel Embiid  PHI  $51415938  $55224526  $57985752
# 2      3           Nikola Jokić  DEN  $51415938  $55224526  $59033114
# 3      4           Kevin Durant  PHO  $51179021  $54708609        NaN
# 4      5           Bradley Beal  PHO  $50203930  $53666270  $57128610
# ..   ...                    ...  ...        ...        ...        ...
# 491  492  Javon Freeman-Liberty  TOR    $100000        NaN        NaN
# 492  493         Erik Stevenson  WAS     $66503        NaN        NaN
# 493  494        Branden Carlson  OKC    $496519        NaN        NaN
# 494  495        Branden Carlson  OKC    $496519        NaN        NaN
# 495  496          Javante McCoy  DET     $47265        NaN        NaN
#
#        2027-28    2028-29 2029-30  Guaranteed      -9999
# 0          NaN        NaN     NaN  $177955191  curryst01
# 1    $62624612  $67263472     NaN  $227250828  embiijo01
# 2    $62841702        NaN     NaN  $165673578  jokicni01
# 3          NaN        NaN     NaN  $105887630  duranke01
# 4          NaN        NaN     NaN  $103870200   bealbr01
# ..         ...        ...     ...         ...        ...
# 491        NaN        NaN     NaN     $100000  freemja01
# 492        NaN        NaN     NaN      $66503  steveer01
# 493        NaN        NaN     NaN     $496519  carlsbr01
# 494        NaN        NaN     NaN     $496519  carlsbr01
# 495        NaN        NaN     NaN      $47265  mccoyja01
#
# [496 rows x 11 columns]
